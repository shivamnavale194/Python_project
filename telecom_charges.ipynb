# %%
import pandas as pd

# %%
data = pd.read_csv(r"G:\Data\Pandas\Py_Project on visualization\data_visualization.csv")

# %%
data
# Out:
#      state  account length  area code phone number international plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 3       OH              84        408     375-9999                yes
# 4       OK              75        415     330-6626                yes
# ...    ...             ...        ...          ...                ...
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %% [raw]
# Analyzing the churn variable

# %%
data.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %% [raw]
# unique

# %%
data['churn'].unique()
# Out:
# array([False,  True])

# %% [raw]
# value_counts()

# %%
A = data['churn'].value_counts()
print(A)
# Out:
# churn
# False    2850
# True      483
# Name: count, dtype: int64

# %%
str(483/3333 * 100) + '%'
# Out:
# '14.491449144914492%'

# %% [raw]
# type()

# %%
type(A)
# Out:
# pandas.core.series.Series

# %% [raw]
# Donut Chart

# %%
plt.pie(A, labels = ['Not Churned', 'Churned'], colors=['Orange','Lime'], startangle=50, shadow=True,radius=2,explode=(0,0.2),autopct='%1.2f%%',
       pctdistance=0.75)

circle=plt.Circle((0,0),1, color='white')
c = plt.gcf()

c.gca().add_artist(circle)

plt.title("Churned vs Non-Churned Customers(DSL)")
plt.show()
